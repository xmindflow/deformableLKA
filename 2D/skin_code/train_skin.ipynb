# %%
from __future__ import division
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
import torch
import torch.optim as optim
from torch.utils.data import DataLoader
from loader import *
import pandas as pd
import glob
import argparse
import nibabel as nib
import numpy as np
import copy
import yaml
from model.vit_seg_modeling import VisionTransformer as ViT_seg
from model.vit_seg_modeling import CONFIGS as CONFIGS_ViT_seg

# %%
parser = argparse.ArgumentParser()
parser.add_argument('--root_path', type=str,
                    default='', help='root dir for data')
parser.add_argument('--dataset', type=str,
                    default='isic2018', help='experiment_name')
parser.add_argument('--list_dir', type=str,
                    default='./lists/lists_Synapse', help='list dir')
parser.add_argument('--num_classes', type=int,
                    default=9, help='output channel of network')
parser.add_argument('--max_iterations', type=int,
                    default=30000, help='maximum epoch number to train')
parser.add_argument('--max_epochs', type=int,
                    default=150, help='maximum epoch number to train')
parser.add_argument('--batch_size', type=int,
                    default=24, help='batch_size per gpu')
parser.add_argument('--n_gpu', type=int, default=1, help='total gpu')
parser.add_argument('--deterministic', type=int,  default=1,
                    help='whether use deterministic training')
parser.add_argument('--base_lr', type=float,  default=0.01,
                    help='segmentation network learning rate')
parser.add_argument('--img_size', type=int,
                    default=256, help='input patch size of network input')
parser.add_argument('--seed', type=int,
                    default=1234, help='random seed')
parser.add_argument('--n_skip', type=int,
                    default=3, help='using number of skip-connect, default is num')
parser.add_argument('--vit_name', type=str,
                    default='R50-ViT-B_16', help='select one vit model')
parser.add_argument('--vit_patches_size', type=int,
                    default=16, help='vit_patches_size, default is 16')
# args = parser.parse_args()
args = parser.parse_args(args=[])

# %%
## Loader
## Hyper parameters
config         = yaml.load(open('./config_skin.yml'), Loader=yaml.FullLoader)
number_classes = int(config['number_classes'])
input_channels = 3
best_val_loss  = np.inf
device = 'cuda' if torch.cuda.is_available() else 'cpu'

data_path = config['path_to_data']  

train_dataset = isic_loader(path_Data = data_path, train = True)
train_loader  = DataLoader(train_dataset, batch_size = int(config['batch_size_tr']), shuffle= True)
val_dataset   = isic_loader(path_Data = data_path, train = False)
val_loader    = DataLoader(val_dataset, batch_size = int(config['batch_size_va']), shuffle= False)

# %%
random.seed(args.seed)
np.random.seed(args.seed)
torch.manual_seed(args.seed)
torch.cuda.manual_seed(args.seed)
dataset_name = args.dataset
dataset_config = {
    'Synapse': {
        'root_path': '',
        'list_dir': '',
        'num_classes': 1,
    },
}
args.num_classes = 1
args.root_path = ''
args.list_dir = ''
args.is_pretrain = True
args.exp = 'TU_' + dataset_name + str(args.img_size)
snapshot_path = "./model_results/{}/{}".format(args.exp, 'TU')
snapshot_path = snapshot_path + '_pretrain' if args.is_pretrain else snapshot_path
snapshot_path += '_' + args.vit_name
snapshot_path = snapshot_path + '_skip' + str(args.n_skip)
snapshot_path = snapshot_path + '_vitpatch' + str(args.vit_patches_size) if args.vit_patches_size!=16 else snapshot_path
snapshot_path = snapshot_path+'_'+str(args.max_iterations)[0:2]+'k' if args.max_iterations != 30000 else snapshot_path
snapshot_path = snapshot_path + '_epo' +str(args.max_epochs) if args.max_epochs != 30 else snapshot_path
snapshot_path = snapshot_path+'_bs'+str(args.batch_size)
snapshot_path = snapshot_path + '_lr' + str(args.base_lr) if args.base_lr != 0.01 else snapshot_path
snapshot_path = snapshot_path + '_'+str(args.img_size)
snapshot_path = snapshot_path + '_s'+str(args.seed) if args.seed!=1234 else snapshot_path

if not os.path.exists(snapshot_path):
    os.makedirs(snapshot_path)
config_vit = CONFIGS_ViT_seg[args.vit_name]
config_vit.n_classes = args.num_classes
config_vit.n_skip = args.n_skip
if args.vit_name.find('R50') != -1:
    config_vit.patches.grid = (int(args.img_size / args.vit_patches_size), int(args.img_size / args.vit_patches_size))
Net = ViT_seg(config_vit, img_size=args.img_size, num_classes=config_vit.n_classes).to(device)

# %%
optimizer = optim.SGD(Net.parameters(), lr=args.base_lr, momentum=0.9, weight_decay=0.0001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor = 0.5, patience = config['patience'])
criteria  = torch.nn.BCELoss()

# %%
for ep in range(int(config['epochs'])):
    Net.train()
    epoch_loss = 0
    for itter, batch in enumerate(train_loader):
        img = batch['image'].to(device, dtype=torch.float)
        msk = batch['mask'].to(device)
        mask_type = torch.float32
        msk = msk.to(device=device, dtype=mask_type)
        msk_pred = Net(img)
        loss          = criteria(msk_pred, msk) 
        optimizer.zero_grad()
        loss.backward()
        epoch_loss += loss.item()
        optimizer.step()  
        if itter%int(float(config['progress_p']) * len(train_loader))==0:
            print(f' Epoch>> {ep+1} and itteration {itter+1} Loss>> {((epoch_loss/(itter+1)))}')
    ## Validation phase
    with torch.no_grad():
        print('val_mode')
        val_loss = 0
        Net.eval()
        for itter, batch in enumerate(val_loader):
            img = batch['image'].to(device, dtype=torch.float)
            msk = batch['mask'].to(device)
            mask_type = torch.float32
            msk = msk.to(device=device, dtype=mask_type)
            msk_pred = Net(img)
            loss = criteria(msk_pred, msk) 
            val_loss += loss.item()
        print(f' validation on epoch>> {ep+1} dice loss>> {(abs(val_loss/(itter+1)))}')     
        mean_val_loss = (val_loss/(itter+1))
        # Check the performance and save the model
        if (mean_val_loss) < best_val_loss:
            print('New best loss, saving...')
            best_val_loss = copy.deepcopy(mean_val_loss)
            state = copy.deepcopy({'model_weights': Net.state_dict(), 'val_loss': best_val_loss})
            torch.save(state, config['saved_model'])

    scheduler.step(mean_val_loss)
    
print('Trainng phase finished')
# Out:
#  Epoch>> 1 and itteration 1 Loss>> 0.6713525056838989
#  Epoch>> 1 and itteration 91 Loss>> 0.4028219772236688
#  Epoch>> 1 and itteration 181 Loss>> 0.38357710797154443
#  Epoch>> 1 and itteration 271 Loss>> 0.3657187595688549
#  Epoch>> 1 and itteration 361 Loss>> 0.35696848865773867
#  Epoch>> 1 and itteration 451 Loss>> 0.33765244406303124
#  Epoch>> 1 and itteration 541 Loss>> 0.3199430010152392
#  Epoch>> 1 and itteration 631 Loss>> 0.3071564765980618
#  Epoch>> 1 and itteration 721 Loss>> 0.29575338292655107
#  Epoch>> 1 and itteration 811 Loss>> 0.28973091795636313
#  Epoch>> 1 and itteration 901 Loss>> 0.2829993542502908
# val_mode
#  validation on epoch>> 1 dice loss>> 0.19406575661756703
# New best loss, saving...
#  Epoch>> 2 and itteration 1 Loss>> 0.13811182975769043
#  Epoch>> 2 and itteration 91 Loss>> 0.18968174541062052
#  Epoch>> 2 and itteration 181 Loss>> 0.23027639584976006
#  Epoch>> 2 and itteration 271 Loss>> 0.21821508584097302
#  Epoch>> 2 and itteration 361 Loss>> 0.21367615019680722
#  Epoch>> 2 and itteration 451 Loss>> 0.2180605567826532
#  Epoch>> 2 and itteration 541 Loss>> 0.2189400327803357
#  Epoch>> 2 and itteration 631 Loss>> 0.21747220263900546
#  Epoch>> 2 and itteration 721 Loss>> 0.21587373126148351
#  Epoch>> 2 and itteration 811 Loss>> 0.20672640038376305
#  Epoch>> 2 and itteration 901 Loss>> 0.20296646628971238
# val_mode
#  validation on epoch>> 2 dice loss>> 0.19933315530476883
#  Epoch>> 3 and itteration 1 Loss>> 0.1810024380683899
#  Epoch>> 3 and itteration 91 Loss>> 0.19797540034402858
#  Epoch>> 3 and itteration 181 Loss>> 0.16792746671367417
#  Epoch>> 3 and itteration 271 Loss>> 0.168084453433972
#  Epoch>> 3 and itteration 361 Loss>> 0.16663229424207165
#  Epoch>> 3 and itteration 451 Loss>> 0.17584138755539966
#  Epoch>> 3 and itteration 541 Loss>> 0.1741690397186828
#  Epoch>> 3 and itteration 631 Loss>> 0.17350862762357938
#  Epoch>> 3 and itteration 721 Loss>> 0.17361467102756944
#  Epoch>> 3 and itteration 811 Loss>> 0.17437116219518584
#  Epoch>> 3 and itteration 901 Loss>> 0.17198883659815153
# val_mode
#  validation on epoch>> 3 dice loss>> 0.21815171873405517
#  Epoch>> 4 and itteration 1 Loss>> 0.186385840177536
#  Epoch>> 4 and itteration 91 Loss>> 0.18483165727293754
#  Epoch>> 4 and itteration 181 Loss>> 0.16586418081466006
#  Epoch>> 4 and itteration 271 Loss>> 0.1705905591168637
#  Epoch>> 4 and itteration 361 Loss>> 0.16871349368027702
#  Epoch>> 4 and itteration 451 Loss>> 0.16652587934618118
#  Epoch>> 4 and itteration 541 Loss>> 0.160449201616419
#  Epoch>> 4 and itteration 631 Loss>> 0.15864813206614056
#  Epoch>> 4 and itteration 721 Loss>> 0.1580536735312556
#  Epoch>> 4 and itteration 811 Loss>> 0.1564319927357918
#  Epoch>> 4 and itteration 901 Loss>> 0.15607506230878712
# val_mode
#  validation on epoch>> 4 dice loss>> 0.23007026195353522
#  Epoch>> 5 and itteration 1 Loss>> 0.033296357840299606
#  Epoch>> 5 and itteration 91 Loss>> 0.1801242208169712
#  Epoch>> 5 and itteration 181 Loss>> 0.158018184897814
#  Epoch>> 5 and itteration 271 Loss>> 0.15162606285094554
#  Epoch>> 5 and itteration 361 Loss>> 0.15342270334217686
#  Epoch>> 5 and itteration 451 Loss>> 0.15595825965993287
#  Epoch>> 5 and itteration 541 Loss>> 0.15274804606413994
#  Epoch>> 5 and itteration 631 Loss>> 0.15162881149094193
#  Epoch>> 5 and itteration 721 Loss>> 0.1500848029196345
#  Epoch>> 5 and itteration 811 Loss>> 0.152785009156761
#  Epoch>> 5 and itteration 901 Loss>> 0.15018969425697967
# val_mode
#  validation on epoch>> 5 dice loss>> 0.1936311828562249
# New best loss, saving...
#  Epoch>> 6 and itteration 1 Loss>> 0.1381254941225052
#  Epoch>> 6 and itteration 91 Loss>> 0.16410011364208474
#  Epoch>> 6 and itteration 181 Loss>> 0.1402516371946144
#  Epoch>> 6 and itteration 271 Loss>> 0.1410958919248018
#  Epoch>> 6 and itteration 361 Loss>> 0.13813298719824185
#  Epoch>> 6 and itteration 451 Loss>> 0.1408809625921552
#  Epoch>> 6 and itteration 541 Loss>> 0.14194574399185048
#  Epoch>> 6 and itteration 631 Loss>> 0.13990940313001066
#  Epoch>> 6 and itteration 721 Loss>> 0.14292763644795808
#  Epoch>> 6 and itteration 811 Loss>> 0.139675655281665
#  Epoch>> 6 and itteration 901 Loss>> 0.13804044900720444
# val_mode
#  validation on epoch>> 6 dice loss>> 0.153436238837921
# New best loss, saving...
#  Epoch>> 7 and itteration 1 Loss>> 0.09143362939357758
#  Epoch>> 7 and itteration 91 Loss>> 0.1404761766687363
#  Epoch>> 7 and itteration 181 Loss>> 0.12885486870201418
#  Epoch>> 7 and itteration 271 Loss>> 0.12163017910468732
#  Epoch>> 7 and itteration 361 Loss>> 0.11928662949001773
#  Epoch>> 7 and itteration 451 Loss>> 0.12042674303525633
#  Epoch>> 7 and itteration 541 Loss>> 0.12990884083992837
#  Epoch>> 7 and itteration 631 Loss>> 0.13207846068926216
#  Epoch>> 7 and itteration 721 Loss>> 0.12935818135273358
#  Epoch>> 7 and itteration 811 Loss>> 0.12638859225967589
#  Epoch>> 7 and itteration 901 Loss>> 0.12984743855529765
# val_mode
#  validation on epoch>> 7 dice loss>> 0.14311598840216355
# New best loss, saving...
#  Epoch>> 8 and itteration 1 Loss>> 0.03894801437854767
#  Epoch>> 8 and itteration 91 Loss>> 0.12786256085958456
#  Epoch>> 8 and itteration 181 Loss>> 0.1316482317814017
#  Epoch>> 8 and itteration 271 Loss>> 0.12885389674276224
#  Epoch>> 8 and itteration 361 Loss>> 0.13503906631795817
#  Epoch>> 8 and itteration 451 Loss>> 0.13425511282821187
#  Epoch>> 8 and itteration 541 Loss>> 0.13540429744504517
#  Epoch>> 8 and itteration 631 Loss>> 0.13304665016981576
#  Epoch>> 8 and itteration 721 Loss>> 0.13254878642851287
#  Epoch>> 8 and itteration 811 Loss>> 0.13214031682474914
#  Epoch>> 8 and itteration 901 Loss>> 0.13201915706455145
# val_mode
#  validation on epoch>> 8 dice loss>> 0.14591406261311074
#  Epoch>> 9 and itteration 1 Loss>> 0.049352068454027176
#  Epoch>> 9 and itteration 91 Loss>> 0.14309996020581042
#  Epoch>> 9 and itteration 181 Loss>> 0.14023562824322702
#  Epoch>> 9 and itteration 271 Loss>> 0.12449579476636605
#  Epoch>> 9 and itteration 361 Loss>> 0.11613649386561727
#  Epoch>> 9 and itteration 451 Loss>> 0.11908319620147116
#  Epoch>> 9 and itteration 541 Loss>> 0.12154394074888855
#  Epoch>> 9 and itteration 631 Loss>> 0.1197732701401703
#  Epoch>> 9 and itteration 721 Loss>> 0.12204078099743337
#  Epoch>> 9 and itteration 811 Loss>> 0.12027453865428742
#  Epoch>> 9 and itteration 901 Loss>> 0.12170916123855259
# val_mode
#  validation on epoch>> 9 dice loss>> 0.17724914971782205
#  Epoch>> 10 and itteration 1 Loss>> 0.15019172430038452
#  Epoch>> 10 and itteration 91 Loss>> 0.120499205222906
#  Epoch>> 10 and itteration 181 Loss>> 0.12833740996474718
#  Epoch>> 10 and itteration 271 Loss>> 0.1224553158981004
#  Epoch>> 10 and itteration 361 Loss>> 0.12626883923656557
#  Epoch>> 10 and itteration 451 Loss>> 0.13256946937521782
#  Epoch>> 10 and itteration 541 Loss>> 0.13168916182657928
#  Epoch>> 10 and itteration 631 Loss>> 0.12988887496422474
#  Epoch>> 10 and itteration 721 Loss>> 0.12859055481659928
#  Epoch>> 10 and itteration 811 Loss>> 0.12703674104129012
#  Epoch>> 10 and itteration 901 Loss>> 0.12630815247278432
# val_mode
#  validation on epoch>> 10 dice loss>> 0.16273746493858604
#  Epoch>> 11 and itteration 1 Loss>> 0.028542395681142807
#  Epoch>> 11 and itteration 91 Loss>> 0.11318694453195229
#  Epoch>> 11 and itteration 181 Loss>> 0.11033462785513691
#  Epoch>> 11 and itteration 271 Loss>> 0.10728303275699985
#  Epoch>> 11 and itteration 361 Loss>> 0.10792103906902498
#  Epoch>> 11 and itteration 451 Loss>> 0.1091240512644934
#  Epoch>> 11 and itteration 541 Loss>> 0.11277173931044208
#  Epoch>> 11 and itteration 631 Loss>> 0.1135514902464585
#  Epoch>> 11 and itteration 721 Loss>> 0.11814108858306101
#  Epoch>> 11 and itteration 811 Loss>> 0.11635415247525518
#  Epoch>> 11 and itteration 901 Loss>> 0.11694623934586722
# val_mode
#  validation on epoch>> 11 dice loss>> 0.14170468809859807
# New best loss, saving...
#  Epoch>> 12 and itteration 1 Loss>> 0.11154535412788391
#  Epoch>> 12 and itteration 91 Loss>> 0.11800386257224031
#  Epoch>> 12 and itteration 181 Loss>> 0.1189298355612307
#  Epoch>> 12 and itteration 271 Loss>> 0.11571496495860199
#  Epoch>> 12 and itteration 361 Loss>> 0.11009767999062495
#  Epoch>> 12 and itteration 451 Loss>> 0.1114453749974855
#  Epoch>> 12 and itteration 541 Loss>> 0.1132381531081116
#  Epoch>> 12 and itteration 631 Loss>> 0.11604180399818485
#  Epoch>> 12 and itteration 721 Loss>> 0.11563101249918775
#  Epoch>> 12 and itteration 811 Loss>> 0.11547165150086955
#  Epoch>> 12 and itteration 901 Loss>> 0.11584056242184092
# val_mode
#  validation on epoch>> 12 dice loss>> 0.15677177614953125
#  Epoch>> 13 and itteration 1 Loss>> 0.03681149333715439
#  Epoch>> 13 and itteration 91 Loss>> 0.12272640525435026
#  Epoch>> 13 and itteration 181 Loss>> 0.1060704005295565
#  Epoch>> 13 and itteration 271 Loss>> 0.1027420899827322
#  Epoch>> 13 and itteration 361 Loss>> 0.10210066516767578
#  Epoch>> 13 and itteration 451 Loss>> 0.10166595992683836
#  Epoch>> 13 and itteration 541 Loss>> 0.10280110451862795
#  Epoch>> 13 and itteration 631 Loss>> 0.10400714289851593
#  Epoch>> 13 and itteration 721 Loss>> 0.10462889788819583
#  Epoch>> 13 and itteration 811 Loss>> 0.10559485861905259
#  Epoch>> 13 and itteration 901 Loss>> 0.11066437584681893
# val_mode
#  validation on epoch>> 13 dice loss>> 0.13818974642291607
# New best loss, saving...
#  Epoch>> 14 and itteration 1 Loss>> 0.08348086476325989
#  Epoch>> 14 and itteration 91 Loss>> 0.10304586177916972
#  Epoch>> 14 and itteration 181 Loss>> 0.10539227340740888
#  Epoch>> 14 and itteration 271 Loss>> 0.10941497198343828
#  Epoch>> 14 and itteration 361 Loss>> 0.10967809274545007
#  Epoch>> 14 and itteration 451 Loss>> 0.11550427890669744
#  Epoch>> 14 and itteration 541 Loss>> 0.11117658387807623
#  Epoch>> 14 and itteration 631 Loss>> 0.10909363246491849
#  Epoch>> 14 and itteration 721 Loss>> 0.1066571299410354
#  Epoch>> 14 and itteration 811 Loss>> 0.10511051506290968
#  Epoch>> 14 and itteration 901 Loss>> 0.1044679850610707
# val_mode
#  validation on epoch>> 14 dice loss>> 0.15548487148395088
#  Epoch>> 15 and itteration 1 Loss>> 0.15846559405326843
#  Epoch>> 15 and itteration 91 Loss>> 0.11765560984693385
#  Epoch>> 15 and itteration 181 Loss>> 0.12005102701835046
#  Epoch>> 15 and itteration 271 Loss>> 0.11008353300763782
#  Epoch>> 15 and itteration 361 Loss>> 0.10978382533039495
#  Epoch>> 15 and itteration 451 Loss>> 0.11863645162235144
#  Epoch>> 15 and itteration 541 Loss>> 0.11296748389040641
#  Epoch>> 15 and itteration 631 Loss>> 0.11208285970344738
#  Epoch>> 15 and itteration 721 Loss>> 0.11131234536265203
#  Epoch>> 15 and itteration 811 Loss>> 0.11083646743235658
#  Epoch>> 15 and itteration 901 Loss>> 0.10992568447466497
# val_mode
#  validation on epoch>> 15 dice loss>> 0.13394819443836867
# New best loss, saving...
#  Epoch>> 16 and itteration 1 Loss>> 0.09812122583389282
#  Epoch>> 16 and itteration 91 Loss>> 0.10458617353463893
#  Epoch>> 16 and itteration 181 Loss>> 0.09445977587129364
#  Epoch>> 16 and itteration 271 Loss>> 0.09263242620672357
#  Epoch>> 16 and itteration 361 Loss>> 0.09692356500960371
#  Epoch>> 16 and itteration 451 Loss>> 0.1010664657187832
#  Epoch>> 16 and itteration 541 Loss>> 0.10044491173813117
#  Epoch>> 16 and itteration 631 Loss>> 0.10006213435392514
#  Epoch>> 16 and itteration 721 Loss>> 0.09932642497106788
#  Epoch>> 16 and itteration 811 Loss>> 0.10023162770745346
#  Epoch>> 16 and itteration 901 Loss>> 0.10156643829751888
# val_mode
#  validation on epoch>> 16 dice loss>> 0.13262265782918364
# New best loss, saving...
#  Epoch>> 17 and itteration 1 Loss>> 0.10109864175319672
#  Epoch>> 17 and itteration 91 Loss>> 0.10731586851793659
#  Epoch>> 17 and itteration 181 Loss>> 0.10029876684944933
#  Epoch>> 17 and itteration 271 Loss>> 0.10914438270458546
#  Epoch>> 17 and itteration 361 Loss>> 0.10741566375692548
#  Epoch>> 17 and itteration 451 Loss>> 0.10493739902097608
#  Epoch>> 17 and itteration 541 Loss>> 0.10230674129840187
#  Epoch>> 17 and itteration 631 Loss>> 0.10034187656580788
#  Epoch>> 17 and itteration 721 Loss>> 0.10310181330801627
#  Epoch>> 17 and itteration 811 Loss>> 0.10186277658468441
#  Epoch>> 17 and itteration 901 Loss>> 0.100132496526194
# val_mode
#  validation on epoch>> 17 dice loss>> 0.13206691282323083
# New best loss, saving...
#  Epoch>> 18 and itteration 1 Loss>> 0.017946932464838028
#  Epoch>> 18 and itteration 91 Loss>> 0.09139465860981535
#  Epoch>> 18 and itteration 181 Loss>> 0.10087911875208438
#  Epoch>> 18 and itteration 271 Loss>> 0.10101352413820715
#  Epoch>> 18 and itteration 361 Loss>> 0.10285642961623183
#  Epoch>> 18 and itteration 451 Loss>> 0.1123311132597355
#  Epoch>> 18 and itteration 541 Loss>> 0.10859133611827428
#  Epoch>> 18 and itteration 631 Loss>> 0.10865970036065097
#  Epoch>> 18 and itteration 721 Loss>> 0.10617475610371065
#  Epoch>> 18 and itteration 811 Loss>> 0.10702088866474706
#  Epoch>> 18 and itteration 901 Loss>> 0.10627440802988646
# val_mode
#  validation on epoch>> 18 dice loss>> 0.13671175728311122
#  Epoch>> 19 and itteration 1 Loss>> 0.0847240686416626
#  Epoch>> 19 and itteration 91 Loss>> 0.08337855710555891
#  Epoch>> 19 and itteration 181 Loss>> 0.08005092043470777
#  Epoch>> 19 and itteration 271 Loss>> 0.0850808871222653
#  Epoch>> 19 and itteration 361 Loss>> 0.08746980136606089
#  Epoch>> 19 and itteration 451 Loss>> 0.09424362785622742
#  Epoch>> 19 and itteration 541 Loss>> 0.09390869010463633
#  Epoch>> 19 and itteration 631 Loss>> 0.09337424796307829
#  Epoch>> 19 and itteration 721 Loss>> 0.09333326914715845
#  Epoch>> 19 and itteration 811 Loss>> 0.09450421604567866
#  Epoch>> 19 and itteration 901 Loss>> 0.09545892023933135
# val_mode
#  validation on epoch>> 19 dice loss>> 0.13978052101795593
#  Epoch>> 20 and itteration 1 Loss>> 0.08038280159235
#  Epoch>> 20 and itteration 91 Loss>> 0.09920146866895996
#  Epoch>> 20 and itteration 181 Loss>> 0.09998316444888793
#  Epoch>> 20 and itteration 271 Loss>> 0.10198992226492765
#  Epoch>> 20 and itteration 361 Loss>> 0.11122554309222424
#  Epoch>> 20 and itteration 451 Loss>> 0.10760648230590471
#  Epoch>> 20 and itteration 541 Loss>> 0.10454350040774524
#  Epoch>> 20 and itteration 631 Loss>> 0.10092217167588496
#  Epoch>> 20 and itteration 721 Loss>> 0.1009050818294514
#  Epoch>> 20 and itteration 811 Loss>> 0.10200940238704627
#  Epoch>> 20 and itteration 901 Loss>> 0.10205049062257304
# val_mode
#  validation on epoch>> 20 dice loss>> 0.1377138537858185
#  Epoch>> 21 and itteration 1 Loss>> 0.04886198788881302
#  Epoch>> 21 and itteration 91 Loss>> 0.08312139080857837
#  Epoch>> 21 and itteration 181 Loss>> 0.08097842665522961
#  Epoch>> 21 and itteration 271 Loss>> 0.08111383732944397
#  Epoch>> 21 and itteration 361 Loss>> 0.0815961338641571
#  Epoch>> 21 and itteration 451 Loss>> 0.08437341805588776
#  Epoch>> 21 and itteration 541 Loss>> 0.08535336220530232
#  Epoch>> 21 and itteration 631 Loss>> 0.08709848926014455
#  Epoch>> 21 and itteration 721 Loss>> 0.09036040685983082
#  Epoch>> 21 and itteration 811 Loss>> 0.0917464329869143
#  Epoch>> 21 and itteration 901 Loss>> 0.09472131496967208
# val_mode
#  validation on epoch>> 21 dice loss>> 0.14739743400091831
#  Epoch>> 22 and itteration 1 Loss>> 0.080873042345047
#  Epoch>> 22 and itteration 91 Loss>> 0.09590626292053488
#  Epoch>> 22 and itteration 181 Loss>> 0.09143562982815899
#  Epoch>> 22 and itteration 271 Loss>> 0.09338960804155172
#  Epoch>> 22 and itteration 361 Loss>> 0.09518468271105078
#  Epoch>> 22 and itteration 451 Loss>> 0.09098144862263932
#  Epoch>> 22 and itteration 541 Loss>> 0.0898843965391575
#  Epoch>> 22 and itteration 631 Loss>> 0.09222200853091837
#  Epoch>> 22 and itteration 721 Loss>> 0.0908565720344342
#  Epoch>> 22 and itteration 811 Loss>> 0.09222483119965243
#  Epoch>> 22 and itteration 901 Loss>> 0.09202802360737976
# val_mode
#  validation on epoch>> 22 dice loss>> 0.13796709653378453
#  Epoch>> 23 and itteration 1 Loss>> 0.05901335924863815
#  Epoch>> 23 and itteration 91 Loss>> 0.08546410055810606
#  Epoch>> 23 and itteration 181 Loss>> 0.08147142019678545
#  Epoch>> 23 and itteration 271 Loss>> 0.08501879826731072
#  Epoch>> 23 and itteration 361 Loss>> 0.10034998440134682
#  Epoch>> 23 and itteration 451 Loss>> 0.09836557982985071
#  Epoch>> 23 and itteration 541 Loss>> 0.09519695570045142
#  Epoch>> 23 and itteration 631 Loss>> 0.09547855010368343
#  Epoch>> 23 and itteration 721 Loss>> 0.09365953660367286
#  Epoch>> 23 and itteration 811 Loss>> 0.09372162141776316
#  Epoch>> 23 and itteration 901 Loss>> 0.09601100659221162
# val_mode
#  validation on epoch>> 23 dice loss>> 0.13767588189821042
#  Epoch>> 24 and itteration 1 Loss>> 0.1375880092382431
#  Epoch>> 24 and itteration 91 Loss>> 0.08263405694902598
#  Epoch>> 24 and itteration 181 Loss>> 0.0846508702993887
#  Epoch>> 24 and itteration 271 Loss>> 0.09385259625436634
#  Epoch>> 24 and itteration 361 Loss>> 0.09099230538135256
#  Epoch>> 24 and itteration 451 Loss>> 0.09119318590443705
#  Epoch>> 24 and itteration 541 Loss>> 0.0907432349009677
#  Epoch>> 24 and itteration 631 Loss>> 0.08810986321944915
#  Epoch>> 24 and itteration 721 Loss>> 0.0908886490779801
#  Epoch>> 24 and itteration 811 Loss>> 0.0892214288719173
#  Epoch>> 24 and itteration 901 Loss>> 0.08979873841506461
# val_mode
#  validation on epoch>> 24 dice loss>> 0.13329794751228513
#  Epoch>> 25 and itteration 1 Loss>> 0.039466045796871185
#  Epoch>> 25 and itteration 91 Loss>> 0.08355986046000988
#  Epoch>> 25 and itteration 181 Loss>> 0.09869541953580238
#  Epoch>> 25 and itteration 271 Loss>> 0.10130206137428205
#  Epoch>> 25 and itteration 361 Loss>> 0.0961293187637367
#  Epoch>> 25 and itteration 451 Loss>> 0.09342845629264669
#  Epoch>> 25 and itteration 541 Loss>> 0.09363412459392975
#  Epoch>> 25 and itteration 631 Loss>> 0.09756277826881825
#  Epoch>> 25 and itteration 721 Loss>> 0.09313040495373505
#  Epoch>> 25 and itteration 811 Loss>> 0.09173352063694365
#  Epoch>> 25 and itteration 901 Loss>> 0.09016071526658258
# val_mode
#  validation on epoch>> 25 dice loss>> 0.13176667710593595
# New best loss, saving...
#  Epoch>> 26 and itteration 1 Loss>> 0.09533064812421799
#  Epoch>> 26 and itteration 91 Loss>> 0.07401813295475401
#  Epoch>> 26 and itteration 181 Loss>> 0.08186616911681482
#  Epoch>> 26 and itteration 271 Loss>> 0.0800975035168093
#  Epoch>> 26 and itteration 361 Loss>> 0.08208039062680712
#  Epoch>> 26 and itteration 451 Loss>> 0.08083446199351099
#  Epoch>> 26 and itteration 541 Loss>> 0.08221218471248357
#  Epoch>> 26 and itteration 631 Loss>> 0.08522067103895067
#  Epoch>> 26 and itteration 721 Loss>> 0.08571308690940913
#  Epoch>> 26 and itteration 811 Loss>> 0.08814980320485467
#  Epoch>> 26 and itteration 901 Loss>> 0.08865203035191181
# val_mode
#  validation on epoch>> 26 dice loss>> 0.13640066463874229
#  Epoch>> 27 and itteration 1 Loss>> 0.04771748185157776
#  Epoch>> 27 and itteration 91 Loss>> 0.07958731554694227
#  Epoch>> 27 and itteration 181 Loss>> 0.07882441997075279
#  Epoch>> 27 and itteration 271 Loss>> 0.07756803302279917
#  Epoch>> 27 and itteration 361 Loss>> 0.08090260110465278
#  Epoch>> 27 and itteration 451 Loss>> 0.07931220620259345
#  Epoch>> 27 and itteration 541 Loss>> 0.08173764233912949
#  Epoch>> 27 and itteration 631 Loss>> 0.08094805112203049
#  Epoch>> 27 and itteration 721 Loss>> 0.08119468251243234
#  Epoch>> 27 and itteration 811 Loss>> 0.08345370939800702
#  Epoch>> 27 and itteration 901 Loss>> 0.08474421190184755
# val_mode
#  validation on epoch>> 27 dice loss>> 0.1309539324039428
# New best loss, saving...
#  Epoch>> 28 and itteration 1 Loss>> 0.03884758800268173
#  Epoch>> 28 and itteration 91 Loss>> 0.0810184537504728
#  Epoch>> 28 and itteration 181 Loss>> 0.08774846302890811
#  Epoch>> 28 and itteration 271 Loss>> 0.08209551205150646
#  Epoch>> 28 and itteration 361 Loss>> 0.08306761475801056
#  Epoch>> 28 and itteration 451 Loss>> 0.08213519345052095
#  Epoch>> 28 and itteration 541 Loss>> 0.08093973182575595
#  Epoch>> 28 and itteration 631 Loss>> 0.07867701531560552
#  Epoch>> 28 and itteration 721 Loss>> 0.08204809681805633
#  Epoch>> 28 and itteration 811 Loss>> 0.08226083527731395
#  Epoch>> 28 and itteration 901 Loss>> 0.08484395644674025
# val_mode
#  validation on epoch>> 28 dice loss>> 0.14083280302332463
#  Epoch>> 29 and itteration 1 Loss>> 0.08137761056423187
#  Epoch>> 29 and itteration 91 Loss>> 0.07937861865406835
#  Epoch>> 29 and itteration 181 Loss>> 0.07239882382487066
#  Epoch>> 29 and itteration 271 Loss>> 0.07264551226860702
#  Epoch>> 29 and itteration 361 Loss>> 0.07660926536365394
#  Epoch>> 29 and itteration 451 Loss>> 0.08136826640246911
#  Epoch>> 29 and itteration 541 Loss>> 0.08403060736578791
#  Epoch>> 29 and itteration 631 Loss>> 0.08801830465508338
#  Epoch>> 29 and itteration 721 Loss>> 0.09083103783294331
#  Epoch>> 29 and itteration 811 Loss>> 0.09212591710274191
#  Epoch>> 29 and itteration 901 Loss>> 0.09008327797137937
# val_mode
#  validation on epoch>> 29 dice loss>> 0.15222275064013985
#  Epoch>> 30 and itteration 1 Loss>> 0.08786224573850632
#  Epoch>> 30 and itteration 91 Loss>> 0.08144562391584718
#  Epoch>> 30 and itteration 181 Loss>> 0.0845422011218677
#  Epoch>> 30 and itteration 271 Loss>> 0.08482283884762508
#  Epoch>> 30 and itteration 361 Loss>> 0.08620023029570022
#  Epoch>> 30 and itteration 451 Loss>> 0.0861992314664395
#  Epoch>> 30 and itteration 541 Loss>> 0.08397757591655591
#  Epoch>> 30 and itteration 631 Loss>> 0.08203084985821518
#  Epoch>> 30 and itteration 721 Loss>> 0.08143784286940002
#  Epoch>> 30 and itteration 811 Loss>> 0.08150691356516813
#  Epoch>> 30 and itteration 901 Loss>> 0.08156693657678236
# val_mode
#  validation on epoch>> 30 dice loss>> 0.1293351652305645
# New best loss, saving...
#  Epoch>> 31 and itteration 1 Loss>> 0.11622011661529541
#  Epoch>> 31 and itteration 91 Loss>> 0.07049321652400298
#  Epoch>> 31 and itteration 181 Loss>> 0.07735825798767541
#  Epoch>> 31 and itteration 271 Loss>> 0.07685252996264678
#  Epoch>> 31 and itteration 361 Loss>> 0.08047696351334246
#  Epoch>> 31 and itteration 451 Loss>> 0.08219284707981837
#  Epoch>> 31 and itteration 541 Loss>> 0.0813198771530869
#  Epoch>> 31 and itteration 631 Loss>> 0.08065582278720361
#  Epoch>> 31 and itteration 721 Loss>> 0.08207738502842378
#  Epoch>> 31 and itteration 811 Loss>> 0.08234223504418693
#  Epoch>> 31 and itteration 901 Loss>> 0.08409197205526715
# val_mode
#  validation on epoch>> 31 dice loss>> 0.12897059122553547
# New best loss, saving...
#  Epoch>> 32 and itteration 1 Loss>> 0.04726937413215637
#  Epoch>> 32 and itteration 91 Loss>> 0.06688806625942771
#  Epoch>> 32 and itteration 181 Loss>> 0.0715625976335813
#  Epoch>> 32 and itteration 271 Loss>> 0.06874926858220758
#  Epoch>> 32 and itteration 361 Loss>> 0.07449550485661527
#  Epoch>> 32 and itteration 451 Loss>> 0.07420831876486837
#  Epoch>> 32 and itteration 541 Loss>> 0.07618000620266839
#  Epoch>> 32 and itteration 631 Loss>> 0.07762182690867366
#  Epoch>> 32 and itteration 721 Loss>> 0.07907617174995735
#  Epoch>> 32 and itteration 811 Loss>> 0.08088639325895215
#  Epoch>> 32 and itteration 901 Loss>> 0.07943842845496522
# val_mode
#  validation on epoch>> 32 dice loss>> 0.14402822712723987
#  Epoch>> 33 and itteration 1 Loss>> 0.07890941202640533
#  Epoch>> 33 and itteration 91 Loss>> 0.07434046521250691
#  Epoch>> 33 and itteration 181 Loss>> 0.07517786895681317
#  Epoch>> 33 and itteration 271 Loss>> 0.07722737041140504
#  Epoch>> 33 and itteration 361 Loss>> 0.07626947687572472
#  Epoch>> 33 and itteration 451 Loss>> 0.0767345064776039
#  Epoch>> 33 and itteration 541 Loss>> 0.07721302876947878
#  Epoch>> 33 and itteration 631 Loss>> 0.07692794972460971
#  Epoch>> 33 and itteration 721 Loss>> 0.07683881799123365
#  Epoch>> 33 and itteration 811 Loss>> 0.07688746989604761
#  Epoch>> 33 and itteration 901 Loss>> 0.0767109432804515
# val_mode
#  validation on epoch>> 33 dice loss>> 0.1300158182187833
#  Epoch>> 34 and itteration 1 Loss>> 0.07195239514112473
#  Epoch>> 34 and itteration 91 Loss>> 0.06953408149490645
#  Epoch>> 34 and itteration 181 Loss>> 0.07100360664070805
#  Epoch>> 34 and itteration 271 Loss>> 0.06936161226603269
#  Epoch>> 34 and itteration 361 Loss>> 0.06592921962203081
#  Epoch>> 34 and itteration 451 Loss>> 0.06684278573700435
#  Epoch>> 34 and itteration 541 Loss>> 0.07035238217293886
#  Epoch>> 34 and itteration 631 Loss>> 0.07041438549266989
#  Epoch>> 34 and itteration 721 Loss>> 0.07333372740253248
#  Epoch>> 34 and itteration 811 Loss>> 0.07531397798559117
#  Epoch>> 34 and itteration 901 Loss>> 0.07614111945707017
# val_mode
#  validation on epoch>> 34 dice loss>> 0.1316081510018917
#  Epoch>> 35 and itteration 1 Loss>> 0.1672680675983429
#  Epoch>> 35 and itteration 91 Loss>> 0.0774619937618519
#  Epoch>> 35 and itteration 181 Loss>> 0.07155875169841872
#  Epoch>> 35 and itteration 271 Loss>> 0.07401317177766528
#  Epoch>> 35 and itteration 361 Loss>> 0.07275996873299707
#  Epoch>> 35 and itteration 451 Loss>> 0.07122394510394091
#  Epoch>> 35 and itteration 541 Loss>> 0.07530607312983126
#  Epoch>> 35 and itteration 631 Loss>> 0.07583227682572372
#  Epoch>> 35 and itteration 721 Loss>> 0.07670936375099457
#  Epoch>> 35 and itteration 811 Loss>> 0.07593904304204442
#  Epoch>> 35 and itteration 901 Loss>> 0.07674344240550311
# val_mode
#  validation on epoch>> 35 dice loss>> 0.13571898135424926
#  Epoch>> 36 and itteration 1 Loss>> 0.1970347762107849
#  Epoch>> 36 and itteration 91 Loss>> 0.0699596681253432
#  Epoch>> 36 and itteration 181 Loss>> 0.07400471992399646
#  Epoch>> 36 and itteration 271 Loss>> 0.07284666310198523
#  Epoch>> 36 and itteration 361 Loss>> 0.074494489762736
#  Epoch>> 36 and itteration 451 Loss>> 0.0726635915179739
#  Epoch>> 36 and itteration 541 Loss>> 0.07224928387724786
#  Epoch>> 36 and itteration 631 Loss>> 0.0757657031133098
#  Epoch>> 36 and itteration 721 Loss>> 0.07678460796401111
#  Epoch>> 36 and itteration 811 Loss>> 0.0762702076473077
#  Epoch>> 36 and itteration 901 Loss>> 0.07875575491647907
# val_mode
#  validation on epoch>> 36 dice loss>> 0.13737063328142216
#  Epoch>> 37 and itteration 1 Loss>> 0.11091698706150055
#  Epoch>> 37 and itteration 91 Loss>> 0.07021547916376002
#  Epoch>> 37 and itteration 181 Loss>> 0.0689175667688868
#  Epoch>> 37 and itteration 271 Loss>> 0.07221505959514816
#  Epoch>> 37 and itteration 361 Loss>> 0.07658052862779215
#  Epoch>> 37 and itteration 451 Loss>> 0.079253441136859
#  Epoch>> 37 and itteration 541 Loss>> 0.0782622756236775
#  Epoch>> 37 and itteration 631 Loss>> 0.07949550385792074
#  Epoch>> 37 and itteration 721 Loss>> 0.08054670189015165
#  Epoch>> 37 and itteration 811 Loss>> 0.08026087734705864
#  Epoch>> 37 and itteration 901 Loss>> 0.08104249712836398
# val_mode
#  validation on epoch>> 37 dice loss>> 0.14216159805152062
#  Epoch>> 38 and itteration 1 Loss>> 0.1286117434501648
#  Epoch>> 38 and itteration 91 Loss>> 0.09366157296840306
#  Epoch>> 38 and itteration 181 Loss>> 0.0944160057941853
#  Epoch>> 38 and itteration 271 Loss>> 0.09079881402495492
#  Epoch>> 38 and itteration 361 Loss>> 0.0870261928427789
#  Epoch>> 38 and itteration 451 Loss>> 0.08758906125836487
#  Epoch>> 38 and itteration 541 Loss>> 0.08351774938841817
#  Epoch>> 38 and itteration 631 Loss>> 0.08234498031782769
#  Epoch>> 38 and itteration 721 Loss>> 0.08069625495766365
#  Epoch>> 38 and itteration 811 Loss>> 0.07910681348558143
#  Epoch>> 38 and itteration 901 Loss>> 0.0794238801270343
# val_mode
#  validation on epoch>> 38 dice loss>> 0.12494739116273791
# New best loss, saving...
#  Epoch>> 39 and itteration 1 Loss>> 0.07406187057495117
#  Epoch>> 39 and itteration 91 Loss>> 0.061765681890832196
#  Epoch>> 39 and itteration 181 Loss>> 0.06843806792935614
#  Epoch>> 39 and itteration 271 Loss>> 0.06871669868014176
#  Epoch>> 39 and itteration 361 Loss>> 0.06988515912031451
#  Epoch>> 39 and itteration 451 Loss>> 0.06886451691492335
#  Epoch>> 39 and itteration 541 Loss>> 0.06951884572030959
#  Epoch>> 39 and itteration 631 Loss>> 0.06870390999274072
#  Epoch>> 39 and itteration 721 Loss>> 0.06906612533055524
#  Epoch>> 39 and itteration 811 Loss>> 0.06930381043454685
#  Epoch>> 39 and itteration 901 Loss>> 0.06892258145398854
# val_mode
#  validation on epoch>> 39 dice loss>> 0.1360332396359661
#  Epoch>> 40 and itteration 1 Loss>> 0.016457438468933105
#  Epoch>> 40 and itteration 91 Loss>> 0.08310505715045301
#  Epoch>> 40 and itteration 181 Loss>> 0.08266660687899556
#  Epoch>> 40 and itteration 271 Loss>> 0.07975237785470826
#  Epoch>> 40 and itteration 361 Loss>> 0.07842817470312655
#  Epoch>> 40 and itteration 451 Loss>> 0.07790098439162792
#  Epoch>> 40 and itteration 541 Loss>> 0.07790547636614738
#  Epoch>> 40 and itteration 631 Loss>> 0.07543183560077273
#  Epoch>> 40 and itteration 721 Loss>> 0.07443594728143119
#  Epoch>> 40 and itteration 811 Loss>> 0.07450599130415317
#  Epoch>> 40 and itteration 901 Loss>> 0.07426906814984771
# val_mode
#  validation on epoch>> 40 dice loss>> 0.1336469946547796
#  Epoch>> 41 and itteration 1 Loss>> 0.09207794070243835
#  Epoch>> 41 and itteration 91 Loss>> 0.08430935565771146
#  Epoch>> 41 and itteration 181 Loss>> 0.07394255145879987
#  Epoch>> 41 and itteration 271 Loss>> 0.07674864971859044
#  Epoch>> 41 and itteration 361 Loss>> 0.07335772873689304
#  Epoch>> 41 and itteration 451 Loss>> 0.07183535789302706
#  Epoch>> 41 and itteration 541 Loss>> 0.0723962780895562
#  Epoch>> 41 and itteration 631 Loss>> 0.07139169980687711
#  Epoch>> 41 and itteration 721 Loss>> 0.0701848531649519
#  Epoch>> 41 and itteration 811 Loss>> 0.06961837566185526
#  Epoch>> 41 and itteration 901 Loss>> 0.07048874593481472
# val_mode
#  validation on epoch>> 41 dice loss>> 0.12512181067486872
#  Epoch>> 42 and itteration 1 Loss>> 0.027584001421928406
#  Epoch>> 42 and itteration 91 Loss>> 0.10492539445736579
#  Epoch>> 42 and itteration 181 Loss>> 0.09638903859632285
#  Epoch>> 42 and itteration 271 Loss>> 0.09105005554469969
#  Epoch>> 42 and itteration 361 Loss>> 0.08455506693107434
#  Epoch>> 42 and itteration 451 Loss>> 0.08219388249988963
#  Epoch>> 42 and itteration 541 Loss>> 0.07918415008054258
#  Epoch>> 42 and itteration 631 Loss>> 0.07905942730741389
#  Epoch>> 42 and itteration 721 Loss>> 0.07735366080906991
#  Epoch>> 42 and itteration 811 Loss>> 0.07864780698095605
#  Epoch>> 42 and itteration 901 Loss>> 0.07919743439631245
# val_mode
#  validation on epoch>> 42 dice loss>> 0.12984952104410954
#  Epoch>> 43 and itteration 1 Loss>> 0.19159084558486938
#  Epoch>> 43 and itteration 91 Loss>> 0.06310764836290708
#  Epoch>> 43 and itteration 181 Loss>> 0.06286983054584067
#  Epoch>> 43 and itteration 271 Loss>> 0.06388601927753414
#  Epoch>> 43 and itteration 361 Loss>> 0.0636801941660839
#  Epoch>> 43 and itteration 451 Loss>> 0.06806579013633854
#  Epoch>> 43 and itteration 541 Loss>> 0.06933747806677563
#  Epoch>> 43 and itteration 631 Loss>> 0.07005333423499378
#  Epoch>> 43 and itteration 721 Loss>> 0.069815033424811
#  Epoch>> 43 and itteration 811 Loss>> 0.0700232079120539
#  Epoch>> 43 and itteration 901 Loss>> 0.06893850244389439
# val_mode
#  validation on epoch>> 43 dice loss>> 0.13445072723588544
#  Epoch>> 44 and itteration 1 Loss>> 0.04014415293931961
#  Epoch>> 44 and itteration 91 Loss>> 0.06804858876781149
#  Epoch>> 44 and itteration 181 Loss>> 0.06643025606397272
#  Epoch>> 44 and itteration 271 Loss>> 0.064460963229013
#  Epoch>> 44 and itteration 361 Loss>> 0.06450500205246902
#  Epoch>> 44 and itteration 451 Loss>> 0.06422724672686102
#  Epoch>> 44 and itteration 541 Loss>> 0.06464198389040675
#  Epoch>> 44 and itteration 631 Loss>> 0.06542573268222733
#  Epoch>> 44 and itteration 721 Loss>> 0.06586374113033945
#  Epoch>> 44 and itteration 811 Loss>> 0.06653575534540723
#  Epoch>> 44 and itteration 901 Loss>> 0.06678483392485106
# val_mode
#  validation on epoch>> 44 dice loss>> 0.1397351034652643
#  Epoch>> 45 and itteration 1 Loss>> 0.06389497965574265
#  Epoch>> 45 and itteration 91 Loss>> 0.06421817771599188
#  Epoch>> 45 and itteration 181 Loss>> 0.07223879063285846
#  Epoch>> 45 and itteration 271 Loss>> 0.07073535797670759
#  Epoch>> 45 and itteration 361 Loss>> 0.06976433522700025
#  Epoch>> 45 and itteration 451 Loss>> 0.06860428705229166
#  Epoch>> 45 and itteration 541 Loss>> 0.07036847618706318
#  Epoch>> 45 and itteration 631 Loss>> 0.07186174515867975
#  Epoch>> 45 and itteration 721 Loss>> 0.07112889941626754
#  Epoch>> 45 and itteration 811 Loss>> 0.0717895470844391
#  Epoch>> 45 and itteration 901 Loss>> 0.07208610840139706
# val_mode
#  validation on epoch>> 45 dice loss>> 0.12815382561383906
#  Epoch>> 46 and itteration 1 Loss>> 0.054589442908763885
#  Epoch>> 46 and itteration 91 Loss>> 0.049011083463063605
#  Epoch>> 46 and itteration 181 Loss>> 0.05977656361929949
#  Epoch>> 46 and itteration 271 Loss>> 0.06354112134442229
#  Epoch>> 46 and itteration 361 Loss>> 0.06040882640273163
#  Epoch>> 46 and itteration 451 Loss>> 0.05969311240255139
#  Epoch>> 46 and itteration 541 Loss>> 0.0626934204214423
#  Epoch>> 46 and itteration 631 Loss>> 0.06332659528689627
#  Epoch>> 46 and itteration 721 Loss>> 0.06344519056839644
#  Epoch>> 46 and itteration 811 Loss>> 0.06354257340844992
#  Epoch>> 46 and itteration 901 Loss>> 0.06504708723465888
# val_mode
#  validation on epoch>> 46 dice loss>> 0.1314840479762901
#  Epoch>> 47 and itteration 1 Loss>> 0.02239799126982689
#  Epoch>> 47 and itteration 91 Loss>> 0.07056631403719331
#  Epoch>> 47 and itteration 181 Loss>> 0.06317620660121763
#  Epoch>> 47 and itteration 271 Loss>> 0.06532357003354224
#  Epoch>> 47 and itteration 361 Loss>> 0.06283187018604201
#  Epoch>> 47 and itteration 451 Loss>> 0.06478031163316575
#  Epoch>> 47 and itteration 541 Loss>> 0.06521566561380206
#  Epoch>> 47 and itteration 631 Loss>> 0.06427540589735006
#  Epoch>> 47 and itteration 721 Loss>> 0.06502274173310597
#  Epoch>> 47 and itteration 811 Loss>> 0.06834454713940492
#  Epoch>> 47 and itteration 901 Loss>> 0.06931787715567385
# val_mode
#  validation on epoch>> 47 dice loss>> 0.13686747658408058
#  Epoch>> 48 and itteration 1 Loss>> 0.15090720355510712
#  Epoch>> 48 and itteration 91 Loss>> 0.07771419795168626
#  Epoch>> 48 and itteration 181 Loss>> 0.07226358300321915
#  Epoch>> 48 and itteration 271 Loss>> 0.07236285348048234
#  Epoch>> 48 and itteration 361 Loss>> 0.06785390009443144
#  Epoch>> 48 and itteration 451 Loss>> 0.06655057260411443
#  Epoch>> 48 and itteration 541 Loss>> 0.06613974446988563
#  Epoch>> 48 and itteration 631 Loss>> 0.06632902610843348
#  Epoch>> 48 and itteration 721 Loss>> 0.06567612064656143
#  Epoch>> 48 and itteration 811 Loss>> 0.06451988075463659
#  Epoch>> 48 and itteration 901 Loss>> 0.06475601580301993
# val_mode
#  validation on epoch>> 48 dice loss>> 0.1415470859025062
#  Epoch>> 49 and itteration 1 Loss>> 0.08206552267074585
#  Epoch>> 49 and itteration 91 Loss>> 0.07735969457816291
#  Epoch>> 49 and itteration 181 Loss>> 0.07015612409115661
#  Epoch>> 49 and itteration 271 Loss>> 0.06983154773286018
#  Epoch>> 49 and itteration 361 Loss>> 0.06872269531861566
#  Epoch>> 49 and itteration 451 Loss>> 0.09193998688992996
#  Epoch>> 49 and itteration 541 Loss>> 0.10297431786804565
#  Epoch>> 49 and itteration 631 Loss>> 0.10674197156655288
#  Epoch>> 49 and itteration 721 Loss>> 0.10700700655915411
#  Epoch>> 49 and itteration 811 Loss>> 0.10608185872977598
#  Epoch>> 49 and itteration 901 Loss>> 0.10639159739240756
# val_mode
#  validation on epoch>> 49 dice loss>> 0.15474453847495745
#  Epoch>> 50 and itteration 1 Loss>> 0.013391890563070774
#  Epoch>> 50 and itteration 91 Loss>> 0.09179502627351782
#  Epoch>> 50 and itteration 181 Loss>> 0.0855618753465335
#  Epoch>> 50 and itteration 271 Loss>> 0.0805105322910081
#  Epoch>> 50 and itteration 361 Loss>> 0.0815308113425062
#  Epoch>> 50 and itteration 451 Loss>> 0.08196002800748611
#  Epoch>> 50 and itteration 541 Loss>> 0.08116859326125321
#  Epoch>> 50 and itteration 631 Loss>> 0.08054229054709221
#  Epoch>> 50 and itteration 721 Loss>> 0.08219568397857549
#  Epoch>> 50 and itteration 811 Loss>> 0.08125983143073728
#  Epoch>> 50 and itteration 901 Loss>> 0.08127492638180792
# val_mode
#  validation on epoch>> 50 dice loss>> 0.15410754941835367
# Trainng phase finished
